# %%
# importing pandas
import pandas as pd

# %%
# Creating dataframe
gen_pay_2021_df = pd.read_csv(r'Data/OP_DTL_GNRL_PGYR2021_P01202023.csv', nrows=500000)
# Out:
# C:\Users\gmula\AppData\Local\Temp/ipykernel_9916/1321523912.py:2: DtypeWarning: Columns (4,8,10,17,18,26,32,33,34,46,47,48,51,53,54,63,64,65,66,67,68,69,70,71,72,73,74,75,77,78,79,80,81,83,84,85,86,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   gen_pay_2021_df = pd.read_csv(r'Data/OP_DTL_GNRL_PGYR2021_P01202023.csv', nrows=500000)

# %%
#Checking number of rows and columns
gen_pay_2021_df.shape
# Out:
# (500000, 91)

# %%
#Checking df info
gen_pay_2021_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 91 columns):
#  #   Column                                                             Non-Null Count   Dtype
# ---  ------                                                             --------------   -----
#  0   Change_Type                                                        500000 non-null  object
#  1   Covered_Recipient_Type                                             500000 non-null  object
#  2   Teaching_Hospital_CCN                                              6719 non-null    float64
#  3   Teaching_Hospital_ID                                               6719 non-null    float64
#  4   Teaching_Hospital_Name                                             6719 non-null    object
#  5   Covered_Recipient_Profile_ID                                       493281 non-null  float64
#  6   Covered_Recipient_NPI                                              493224 non-null  float64
#  7   Covered_Recipient_First_Name                                       493277 non-null  object
#  8   Covered_Recipient_Middle_Name                                      20156 non-null   object
#  9   Covered_Recipient_Last_Name                                        493280 non-null  object
#  10  Covered_Recipient_Name_Suffix                                      799 non-null     object
#  11  Recipient_Primary_Business_Street_Address_Line1                    500000 non-null  object
#  12  Recipient_Primary_Business_Street_Address_Line2                    157016 non-null  object
#  13  Recipient_City                                                     500000 non-null  object
#  14  Recipient_State                                                    499964 non-null  object
#  15  Recipient_Zip_Code                                                 499964 non-null  object
#  16  Recipient_Country                                                  500000 non-null  object
#  17  Recipient_Province                                                 8 non-null       object
#  18  Recipient_Postal_Code                                              36 non-null      object
#  19  Covered_Recipient_Primary_Type_1                                   493281 non-null  object
#  20  Covered_Recipient_Primary_Type_2                                   0 non-null       float64
#  21  Covered_Recipient_Primary_Type_3                                   0 non-null       float64
#  22  Covered_Recipient_Primary_Type_4                                   0 non-null       float64
#  23  Covered_Recipient_Primary_Type_5                                   0 non-null       float64
#  24  Covered_Recipient_Primary_Type_6                                   0 non-null       float64
#  25  Covered_Recipient_Specialty_1                                      493274 non-null  object
#  26  Covered_Recipient_Specialty_2                                      2 non-null       object
#  27  Covered_Recipient_Specialty_3                                      0 non-null       float64
#  28  Covered_Recipient_Specialty_4                                      0 non-null       float64
#  29  Covered_Recipient_Specialty_5                                      0 non-null       float64
#  30  Covered_Recipient_Specialty_6                                      0 non-null       float64
#  31  Covered_Recipient_License_State_code1                              493281 non-null  object
#  32  Covered_Recipient_License_State_code2                              1462 non-null    object
#  33  Covered_Recipient_License_State_code3                              167 non-null     object
#  34  Covered_Recipient_License_State_code4                              5 non-null       object
#  35  Covered_Recipient_License_State_code5                              0 non-null       float64
#  36  Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name          500000 non-null  object
#  37  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID        500000 non-null  int64
#  38  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name      500000 non-null  object
#  39  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State     495049 non-null  object
#  40  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country   500000 non-null  object
#  41  Total_Amount_of_Payment_USDollars                                  500000 non-null  float64
#  42  Date_of_Payment                                                    500000 non-null  object
#  43  Number_of_Payments_Included_in_Total_Amount                        500000 non-null  int64
#  44  Form_of_Payment_or_Transfer_of_Value                               500000 non-null  object
#  45  Nature_of_Payment_or_Transfer_of_Value                             500000 non-null  object
#  46  City_of_Travel                                                     7678 non-null    object
#  47  State_of_Travel                                                    7547 non-null    object
#  48  Country_of_Travel                                                  7678 non-null    object
#  49  Physician_Ownership_Indicator                                      365014 non-null  object
#  50  Third_Party_Payment_Recipient_Indicator                            500000 non-null  object
#  51  Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value  5346 non-null    object
#  52  Charity_Indicator                                                  471689 non-null  object
#  53  Third_Party_Equals_Covered_Recipient_Indicator                     6060 non-null    object
#  54  Contextual_Information                                             11709 non-null   object
#  55  Delay_in_Publication_Indicator                                     500000 non-null  object
#  56  Record_ID                                                          500000 non-null  int64
#  57  Dispute_Status_for_Publication                                     500000 non-null  object
#  58  Related_Product_Indicator                                          500000 non-null  object
#  59  Covered_or_Noncovered_Indicator_1                                  471715 non-null  object
#  60  Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1          468713 non-null  object
#  61  Product_Category_or_Therapeutic_Area_1                             467376 non-null  object
#  62  Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1           465651 non-null  object
#  63  Associated_Drug_or_Biological_NDC_1                                345293 non-null  object
#  64  Associated_Device_or_Medical_Supply_PDI_1                          86061 non-null   object
#  65  Covered_or_Noncovered_Indicator_2                                  118834 non-null  object
#  66  Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2          118787 non-null  object
#  67  Product_Category_or_Therapeutic_Area_2                             118273 non-null  object
#  68  Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2           118026 non-null  object
#  69  Associated_Drug_or_Biological_NDC_2                                96485 non-null   object
#  70  Associated_Device_or_Medical_Supply_PDI_2                          21914 non-null   object
#  71  Covered_or_Noncovered_Indicator_3                                  53307 non-null   object
#  72  Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3          53302 non-null   object
#  73  Product_Category_or_Therapeutic_Area_3                             53101 non-null   object
#  74  Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3           52992 non-null   object
#  75  Associated_Drug_or_Biological_NDC_3                                45902 non-null   object
#  76  Associated_Device_or_Medical_Supply_PDI_3                          7333 non-null    float64
#  77  Covered_or_Noncovered_Indicator_4                                  44576 non-null   object
#  78  Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4          44575 non-null   object
#  79  Product_Category_or_Therapeutic_Area_4                             44493 non-null   object
#  80  Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4           44451 non-null   object
#  81  Associated_Drug_or_Biological_NDC_4                                42179 non-null   object
#  82  Associated_Device_or_Medical_Supply_PDI_4                          2390 non-null    float64
#  83  Covered_or_Noncovered_Indicator_5                                  681 non-null     object
#  84  Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5          681 non-null     object
#  85  Product_Category_or_Therapeutic_Area_5                             681 non-null     object
#  86  Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5           654 non-null     object
#  87  Associated_Drug_or_Biological_NDC_5                                109 non-null     object
#  88  Associated_Device_or_Medical_Supply_PDI_5                          572 non-null     float64
#  89  Program_Year                                                       500000 non-null  int64
#  90  Payment_Publication_Date                                           500000 non-null  object
# dtypes: float64(18), int64(4), object(69)
# memory usage: 347.1+ MB

# %%
# Checking top 5 rows of data
gen_pay_2021_df.head(5)
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN
# 0   UNCHANGED  Covered Recipient Physician                    NaN  \
# 1   UNCHANGED  Covered Recipient Physician                    NaN
# 2   UNCHANGED  Covered Recipient Physician                    NaN
# 3   UNCHANGED  Covered Recipient Physician                    NaN
# 4   UNCHANGED  Covered Recipient Physician                    NaN
#
#    Teaching_Hospital_ID Teaching_Hospital_Name  Covered_Recipient_Profile_ID
# 0                   NaN                    NaN                       92058.0  \
# 1                   NaN                    NaN                     1231338.0
# 2                   NaN                    NaN                      992939.0
# 3                   NaN                    NaN                      774776.0
# 4                   NaN                    NaN                      106575.0
#
#    Covered_Recipient_NPI Covered_Recipient_First_Name
# 0           1.043218e+09                         Ahad  \
# 1           1.487818e+09                       Arsham
# 2           1.104822e+09                       Donato
# 3           1.457355e+09                         Earl
# 4           1.346417e+09                      Michael
#
#   Covered_Recipient_Middle_Name Covered_Recipient_Last_Name  ...
# 0                           NaN                   Mahootchi  ...  \
# 1                           NaN                    Sheybani  ...
# 2                             J                    Borrillo  ...
# 3                           NaN                      Craven  ...
# 4                             J                       Bauer  ...
#
#   Associated_Drug_or_Biological_NDC_4
# 0                                 NaN  \
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   Associated_Device_or_Medical_Supply_PDI_4 Covered_or_Noncovered_Indicator_5
# 0                                       NaN                               NaN  \
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 4                                       NaN                               NaN
#
#   Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5
# 0                                                NaN         \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Product_Category_or_Therapeutic_Area_5
# 0                                    NaN  \
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5
# 0                                                NaN        \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Associated_Drug_or_Biological_NDC_5
# 0                                 NaN  \
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   Associated_Device_or_Medical_Supply_PDI_5 Program_Year
# 0                                       NaN         2021  \
# 1                                       NaN         2021
# 2                                       NaN         2021
# 3                                       NaN         2021
# 4                                       NaN         2021
#
#   Payment_Publication_Date
# 0               01/20/2023
# 1               01/20/2023
# 2               01/20/2023
# 3               01/20/2023
# 4               01/20/2023
#
# [5 rows x 91 columns]

# %%
#Check nulls
gen_pay_2021_df.isnull().sum()
# Out:
# Change_Type                                                      0
# Covered_Recipient_Type                                           0
# Teaching_Hospital_CCN                                       493281
# Teaching_Hospital_ID                                        493281
# Teaching_Hospital_Name                                      493281
#                                                              ...
# Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5    499346
# Associated_Drug_or_Biological_NDC_5                         499891
# Associated_Device_or_Medical_Supply_PDI_5                   499428
# Program_Year                                                     0
# Payment_Publication_Date                                         0
# Length: 91, dtype: int64

# %%
# Checking columns
gen_pay_2021_df.columns
# Out:
# Index(['Change_Type', 'Covered_Recipient_Type', 'Teaching_Hospital_CCN',
#        'Teaching_Hospital_ID', 'Teaching_Hospital_Name',
#        'Covered_Recipient_Profile_ID', 'Covered_Recipient_NPI',
#        'Covered_Recipient_First_Name', 'Covered_Recipient_Middle_Name',
#        'Covered_Recipient_Last_Name', 'Covered_Recipient_Name_Suffix',
#        'Recipient_Primary_Business_Street_Address_Line1',
#        'Recipient_Primary_Business_Street_Address_Line2', 'Recipient_City',
#        'Recipient_State', 'Recipient_Zip_Code', 'Recipient_Country',
#        'Recipient_Province', 'Recipient_Postal_Code',
#        'Covered_Recipient_Primary_Type_1', 'Covered_Recipient_Primary_Type_2',
#        'Covered_Recipient_Primary_Type_3', 'Covered_Recipient_Primary_Type_4',
#        'Covered_Recipient_Primary_Type_5', 'Covered_Recipient_Primary_Type_6',
#        'Covered_Recipient_Specialty_1', 'Covered_Recipient_Specialty_2',
#        'Covered_Recipient_Specialty_3', 'Covered_Recipient_Specialty_4',
#        'Covered_Recipient_Specialty_5', 'Covered_Recipient_Specialty_6',
#        'Covered_Recipient_License_State_code1',
#        'Covered_Recipient_License_State_code2',
#        'Covered_Recipient_License_State_code3',
#        'Covered_Recipient_License_State_code4',
#        'Covered_Recipient_License_State_code5',
#        'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country',
#        'Total_Amount_of_Payment_USDollars', 'Date_of_Payment',
#        'Number_of_Payments_Included_in_Total_Amount',
#        'Form_of_Payment_or_Transfer_of_Value',
#        'Nature_of_Payment_or_Transfer_of_Value', 'City_of_Travel',
#        'State_of_Travel', 'Country_of_Travel', 'Physician_Ownership_Indicator',
#        'Third_Party_Payment_Recipient_Indicator',
#        'Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value',
#        'Charity_Indicator', 'Third_Party_Equals_Covered_Recipient_Indicator',
#        'Contextual_Information', 'Delay_in_Publication_Indicator', 'Record_ID',
#        'Dispute_Status_for_Publication', 'Related_Product_Indicator',
#        'Covered_or_Noncovered_Indicator_1',
#        'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1',
#        'Product_Category_or_Therapeutic_Area_1',
#        'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1',
#        'Associated_Drug_or_Biological_NDC_1',
#        'Associated_Device_or_Medical_Supply_PDI_1',
#        'Covered_or_Noncovered_Indicator_2',
#        'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2',
#        'Product_Category_or_Therapeutic_Area_2',
#        'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2',
#        'Associated_Drug_or_Biological_NDC_2',
#        'Associated_Device_or_Medical_Supply_PDI_2',
#        'Covered_or_Noncovered_Indicator_3',
#        'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3',
#        'Product_Category_or_Therapeutic_Area_3',
#        'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3',
#        'Associated_Drug_or_Biological_NDC_3',
#        'Associated_Device_or_Medical_Supply_PDI_3',
#        'Covered_or_Noncovered_Indicator_4',
#        'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4',
#        'Product_Category_or_Therapeutic_Area_4',
#        'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4',
#        'Associated_Drug_or_Biological_NDC_4',
#        'Associated_Device_or_Medical_Supply_PDI_4',
#        'Covered_or_Noncovered_Indicator_5',
#        'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5',
#        'Product_Category_or_Therapeutic_Area_5',
#        'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5',
#        'Associated_Drug_or_Biological_NDC_5',
#        'Associated_Device_or_Medical_Supply_PDI_5', 'Program_Year',
#        'Payment_Publication_Date'],
#       dtype='object')

# %%
# drop columns
gen_pay_2021_df = gen_pay_2021_df.drop(columns = ['Covered_Recipient_Middle_Name','Covered_Recipient_Name_Suffix','Recipient_Province',
                                     'Recipient_Postal_Code','Contextual_Information','Covered_or_Noncovered_Indicator_1',
                                     'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1','Product_Category_or_Therapeutic_Area_1',
                                     'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1','Associated_Drug_or_Biological_NDC_1',
                                     'Associated_Device_or_Medical_Supply_PDI_1','Covered_or_Noncovered_Indicator_2',
                                     'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2','Product_Category_or_Therapeutic_Area_2',
                                     'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2','Associated_Drug_or_Biological_NDC_2',
                                     'Associated_Device_or_Medical_Supply_PDI_2','Covered_or_Noncovered_Indicator_3',
                                     'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3','Product_Category_or_Therapeutic_Area_3',
                                     'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3','Associated_Drug_or_Biological_NDC_3',
                                     'Associated_Device_or_Medical_Supply_PDI_3','Covered_or_Noncovered_Indicator_4',
                                     'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4','Product_Category_or_Therapeutic_Area_4',
                                     'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4','Associated_Drug_or_Biological_NDC_4',
                                     'Associated_Device_or_Medical_Supply_PDI_4','Covered_or_Noncovered_Indicator_5',
                                     'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5','Product_Category_or_Therapeutic_Area_5',
                                     'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5','Associated_Drug_or_Biological_NDC_5',
                                     'Associated_Device_or_Medical_Supply_PDI_5','Covered_Recipient_Specialty_2',
                                     'Covered_Recipient_Specialty_3','Covered_Recipient_Specialty_4', 'Covered_Recipient_Specialty_5',
                                     'Covered_Recipient_Specialty_6','Covered_Recipient_Primary_Type_2','Covered_Recipient_Primary_Type_3',
                                     'Covered_Recipient_Primary_Type_4','Covered_Recipient_Primary_Type_5', 
                                     'Covered_Recipient_Primary_Type_6','Covered_Recipient_License_State_code5'])

# %%
# Updating Date data types
gen_pay_2021_df['Date_of_Payment'] = pd.to_datetime(gen_pay_2021_df["Date_of_Payment"])
gen_pay_2021_df['Date_of_Payment']
# Out:
# 0        2021-05-26
# 1        2021-05-26
# 2        2021-06-16
# 3        2021-01-13
# 4        2021-12-07
#             ...
# 499995   2021-11-23
# 499996   2021-05-03
# 499997   2021-12-21
# 499998   2021-08-24
# 499999   2021-02-08
# Name: Date_of_Payment, Length: 500000, dtype: datetime64[ns]

# %%
# Updating Date data types
gen_pay_2021_df['Payment_Publication_Date'] = pd.to_datetime(gen_pay_2021_df["Payment_Publication_Date"])

# %%
gen_pay_2021_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 45 columns):
#  #   Column                                                             Non-Null Count   Dtype
# ---  ------                                                             --------------   -----
#  0   Change_Type                                                        500000 non-null  object
#  1   Covered_Recipient_Type                                             500000 non-null  object
#  2   Teaching_Hospital_CCN                                              6719 non-null    float64
#  3   Teaching_Hospital_ID                                               6719 non-null    float64
#  4   Teaching_Hospital_Name                                             6719 non-null    object
#  5   Covered_Recipient_Profile_ID                                       493281 non-null  float64
#  6   Covered_Recipient_NPI                                              493224 non-null  float64
#  7   Covered_Recipient_First_Name                                       493277 non-null  object
#  8   Covered_Recipient_Last_Name                                        493280 non-null  object
#  9   Recipient_Primary_Business_Street_Address_Line1                    500000 non-null  object
#  10  Recipient_Primary_Business_Street_Address_Line2                    157016 non-null  object
#  11  Recipient_City                                                     500000 non-null  object
#  12  Recipient_State                                                    499964 non-null  object
#  13  Recipient_Zip_Code                                                 499964 non-null  object
#  14  Recipient_Country                                                  500000 non-null  object
#  15  Covered_Recipient_Primary_Type_1                                   493281 non-null  object
#  16  Covered_Recipient_Specialty_1                                      493274 non-null  object
#  17  Covered_Recipient_License_State_code1                              493281 non-null  object
#  18  Covered_Recipient_License_State_code2                              1462 non-null    object
#  19  Covered_Recipient_License_State_code3                              167 non-null     object
#  20  Covered_Recipient_License_State_code4                              5 non-null       object
#  21  Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name          500000 non-null  object
#  22  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID        500000 non-null  int64
#  23  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name      500000 non-null  object
#  24  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State     495049 non-null  object
#  25  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country   500000 non-null  object
#  26  Total_Amount_of_Payment_USDollars                                  500000 non-null  float64
#  27  Date_of_Payment                                                    500000 non-null  datetime64[ns]
#  28  Number_of_Payments_Included_in_Total_Amount                        500000 non-null  int64
#  29  Form_of_Payment_or_Transfer_of_Value                               500000 non-null  object
#  30  Nature_of_Payment_or_Transfer_of_Value                             500000 non-null  object
#  31  City_of_Travel                                                     7678 non-null    object
#  32  State_of_Travel                                                    7547 non-null    object
#  33  Country_of_Travel                                                  7678 non-null    object
#  34  Physician_Ownership_Indicator                                      365014 non-null  object
#  35  Third_Party_Payment_Recipient_Indicator                            500000 non-null  object
#  36  Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value  5346 non-null    object
#  37  Charity_Indicator                                                  471689 non-null  object
#  38  Third_Party_Equals_Covered_Recipient_Indicator                     6060 non-null    object
#  39  Delay_in_Publication_Indicator                                     500000 non-null  object
#  40  Record_ID                                                          500000 non-null  int64
#  41  Dispute_Status_for_Publication                                     500000 non-null  object
#  42  Related_Product_Indicator                                          500000 non-null  object
#  43  Program_Year                                                       500000 non-null  int64
#  44  Payment_Publication_Date                                           500000 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(5), int64(4), object(34)
# memory usage: 171.7+ MB

# %%
gen_pay_2021_df.head(5)
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN
# 0   UNCHANGED  Covered Recipient Physician                    NaN  \
# 1   UNCHANGED  Covered Recipient Physician                    NaN
# 2   UNCHANGED  Covered Recipient Physician                    NaN
# 3   UNCHANGED  Covered Recipient Physician                    NaN
# 4   UNCHANGED  Covered Recipient Physician                    NaN
#
#    Teaching_Hospital_ID Teaching_Hospital_Name  Covered_Recipient_Profile_ID
# 0                   NaN                    NaN                       92058.0  \
# 1                   NaN                    NaN                     1231338.0
# 2                   NaN                    NaN                      992939.0
# 3                   NaN                    NaN                      774776.0
# 4                   NaN                    NaN                      106575.0
#
#    Covered_Recipient_NPI Covered_Recipient_First_Name
# 0           1.043218e+09                         Ahad  \
# 1           1.487818e+09                       Arsham
# 2           1.104822e+09                       Donato
# 3           1.457355e+09                         Earl
# 4           1.346417e+09                      Michael
#
#   Covered_Recipient_Last_Name Recipient_Primary_Business_Street_Address_Line1
# 0                   Mahootchi                                  6739 Gall Blvd  \
# 1                    Sheybani                            4901 Forest Park Ave
# 2                    Borrillo                               606 Jacqueline Ct
# 3                      Craven                         9910 Franklin Square Dr
# 4                       Bauer                   200 South Wilcox Street, #443
#
#    ... Third_Party_Payment_Recipient_Indicator
# 0  ...                  No Third Party Payment  \
# 1  ...                  No Third Party Payment
# 2  ...                  No Third Party Payment
# 3  ...                  No Third Party Payment
# 4  ...                  No Third Party Payment
#
#   Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value
# 0                                                NaN                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Charity_Indicator Third_Party_Equals_Covered_Recipient_Indicator
# 0                No                                            NaN  \
# 1                No                                            NaN
# 2                No                                            NaN
# 3                No                                            NaN
# 4               NaN                                            NaN
#
#   Delay_in_Publication_Indicator  Record_ID Dispute_Status_for_Publication
# 0                             No  754966348                             No  \
# 1                             No  754966336                             No
# 2                             No  754966512                             No
# 3                             No  754966356                             No
# 4                             No  755632236                             No
#
#   Related_Product_Indicator Program_Year Payment_Publication_Date
# 0                       Yes         2021               2023-01-20
# 1                       Yes         2021               2023-01-20
# 2                       Yes         2021               2023-01-20
# 3                       Yes         2021               2023-01-20
# 4                        No         2021               2023-01-20
#
# [5 rows x 45 columns]

# %%
# Extracted cleaned data to csv
gen_pay_2021_df.to_csv('cleaned-gen-pay-2021-data.csv', index=False)
