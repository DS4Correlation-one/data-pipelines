# %%
import pandas as pd

# %%
df=pd.read_csv("data2021.csv")
df.head(10)
# Out:
#   change_type  physician_profile_id  physician_npi physician_first_name  \
# 0   UNCHANGED                161867   1.568413e+09          Christopher
# 1   UNCHANGED                161599   1.578583e+09              William
# 2   UNCHANGED                  2198   1.053398e+09                 John
# 3   UNCHANGED                267325   1.891892e+09                DAVID
# 4   UNCHANGED               1179193   1.669403e+09               Daniel
# 5   UNCHANGED                325817   1.174574e+09              JEFFREY
# 6   UNCHANGED                184226   1.073567e+09               Kambiz
# 7   UNCHANGED                529732   1.851352e+09               Sriram
# 8   UNCHANGED                206615   1.548343e+09                Julio
# 9   UNCHANGED                246476   1.427158e+09              Richard
#
#   physician_middle_name physician_last_name physician_name_suffix  \
# 0                   NaN              Coogan                   NaN
# ...

# %%
#Remove the first column
df.drop(df.index[[0]], inplace=True)
df.head()
# Out:
#   change_type  physician_profile_id  physician_npi physician_first_name  \
# 1   UNCHANGED                161599   1.578583e+09              William
# 2   UNCHANGED                  2198   1.053398e+09                 John
# 3   UNCHANGED                267325   1.891892e+09                DAVID
# 4   UNCHANGED               1179193   1.669403e+09               Daniel
# 5   UNCHANGED                325817   1.174574e+09              JEFFREY
#
#   physician_middle_name physician_last_name physician_name_suffix  \
# 1                   NaN                Cook                   NaN
# 2                     J             Cudecki                   NaN
# 3                     L          CUNNINGHAM                   NaN
# 4                   NaN              Dalton                   NaN
# 5                ARTHUR                DANN                   NaN
#
#   recipient_primary_business_street_address_line1  \
# 1                    10901 East 48th Street South
# ...

# %%
df = df.drop('change_type',1)
df=df.drop('physician_middle_name',1)
df=df.drop('physician_name_suffix',1)
df=df.drop('recipient_primary_business_street_address_line2' , 1)

df=df.drop('recipient_postal_code',1)
df=df.drop('recipient_province',1)
df.head()
# Out:
# <ipython-input-4-4694278b07b4>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('change_type',1)
# <ipython-input-4-4694278b07b4>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df=df.drop('physician_middle_name',1)
# <ipython-input-4-4694278b07b4>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df=df.drop('physician_name_suffix',1)
# <ipython-input-4-4694278b07b4>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df=df.drop('recipient_primary_business_street_address_line2' , 1)
# ...

# %%
df.shape
# Out:
# (3128, 24)

# %%
df
# Out:
#       physician_profile_id  physician_npi physician_first_name  \
# 1                   161599   1.578583e+09              William
# 2                     2198   1.053398e+09                 John
# 3                   267325   1.891892e+09                DAVID
# 4                  1179193   1.669403e+09               Daniel
# 5                   325817   1.174574e+09              JEFFREY
# ...                    ...            ...                  ...
# 3124               2792709   1.487974e+09                Ralph
# 3125                141844   1.134331e+09               Ernest
# 3126                 26502   1.578761e+09          Jane-Claire
# 3127                 98438   1.184612e+09                 Mark
# 3128                199913   1.417946e+09              Cynthia
#
#      physician_last_name recipient_primary_business_street_address_line1  \
# 1                   Cook                    10901 East 48th Street South
# ...

# %%
df.to_csv('cleaned-data2021.csv', index=False)
