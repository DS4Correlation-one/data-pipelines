# %%
# importing pandas
import pandas as pd

# %%
# Creating dataframe
gen_pay_2020_df = pd.read_csv('Data/OP_DTL_GNRL_PGYR2020_P01202023.csv')
# Out:
# C:\Users\gmula\AppData\Local\Temp/ipykernel_21512/3201377179.py:2: DtypeWarning: Columns (4,8,10,12,15,17,18,32,33,34,35,39,46,47,48,51,52,53,54,60,61,62,63,65,66,67,68,69,71,72,73,74,75,77,78,79,80,81,83,84,85,86,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   gen_pay_2020_df = pd.read_csv('Data/OP_DTL_GNRL_PGYR2020_P01202023.csv')

# %%
#Checking number of rows and columns
gen_pay_2020_df.shape
# Out:
# (5823162, 91)

# %%
#Checking df info
gen_pay_2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5823162 entries, 0 to 5823161
# Data columns (total 91 columns):
#  #   Column                                                             Dtype
# ---  ------                                                             -----
#  0   Change_Type                                                        object
#  1   Covered_Recipient_Type                                             object
#  2   Teaching_Hospital_CCN                                              float64
#  3   Teaching_Hospital_ID                                               float64
#  4   Teaching_Hospital_Name                                             object
#  5   Covered_Recipient_Profile_ID                                       float64
#  6   Covered_Recipient_NPI                                              float64
#  7   Covered_Recipient_First_Name                                       object
#  8   Covered_Recipient_Middle_Name                                      object
#  9   Covered_Recipient_Last_Name                                        object
#  10  Covered_Recipient_Name_Suffix                                      object
#  11  Recipient_Primary_Business_Street_Address_Line1                    object
#  12  Recipient_Primary_Business_Street_Address_Line2                    object
#  13  Recipient_City                                                     object
#  14  Recipient_State                                                    object
#  15  Recipient_Zip_Code                                                 object
#  16  Recipient_Country                                                  object
#  17  Recipient_Province                                                 object
#  18  Recipient_Postal_Code                                              object
#  19  Covered_Recipient_Primary_Type_1                                   object
#  20  Covered_Recipient_Primary_Type_2                                   float64
#  21  Covered_Recipient_Primary_Type_3                                   float64
#  22  Covered_Recipient_Primary_Type_4                                   float64
#  23  Covered_Recipient_Primary_Type_5                                   float64
#  24  Covered_Recipient_Primary_Type_6                                   float64
#  25  Covered_Recipient_Specialty_1                                      object
#  26  Covered_Recipient_Specialty_2                                      float64
#  27  Covered_Recipient_Specialty_3                                      float64
#  28  Covered_Recipient_Specialty_4                                      float64
#  29  Covered_Recipient_Specialty_5                                      float64
#  30  Covered_Recipient_Specialty_6                                      float64
#  31  Covered_Recipient_License_State_code1                              object
#  32  Covered_Recipient_License_State_code2                              object
#  33  Covered_Recipient_License_State_code3                              object
#  34  Covered_Recipient_License_State_code4                              object
#  35  Covered_Recipient_License_State_code5                              object
#  36  Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name          object
#  37  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID        int64
#  38  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name      object
#  39  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State     object
#  40  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country   object
#  41  Total_Amount_of_Payment_USDollars                                  float64
#  42  Date_of_Payment                                                    object
#  43  Number_of_Payments_Included_in_Total_Amount                        int64
#  44  Form_of_Payment_or_Transfer_of_Value                               object
#  45  Nature_of_Payment_or_Transfer_of_Value                             object
#  46  City_of_Travel                                                     object
#  47  State_of_Travel                                                    object
#  48  Country_of_Travel                                                  object
#  49  Physician_Ownership_Indicator                                      object
#  50  Third_Party_Payment_Recipient_Indicator                            object
#  51  Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value  object
#  52  Charity_Indicator                                                  object
#  53  Third_Party_Equals_Covered_Recipient_Indicator                     object
#  54  Contextual_Information                                             object
#  55  Delay_in_Publication_Indicator                                     object
#  56  Record_ID                                                          int64
#  57  Dispute_Status_for_Publication                                     object
#  58  Related_Product_Indicator                                          object
#  59  Covered_or_Noncovered_Indicator_1                                  object
#  60  Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1          object
#  61  Product_Category_or_Therapeutic_Area_1                             object
#  62  Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1           object
#  63  Associated_Drug_or_Biological_NDC_1                                object
#  64  Associated_Device_or_Medical_Supply_PDI_1                          float64
#  65  Covered_or_Noncovered_Indicator_2                                  object
#  66  Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2          object
#  67  Product_Category_or_Therapeutic_Area_2                             object
#  68  Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2           object
#  69  Associated_Drug_or_Biological_NDC_2                                object
#  70  Associated_Device_or_Medical_Supply_PDI_2                          float64
#  71  Covered_or_Noncovered_Indicator_3                                  object
#  72  Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3          object
#  73  Product_Category_or_Therapeutic_Area_3                             object
#  74  Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3           object
#  75  Associated_Drug_or_Biological_NDC_3                                object
#  76  Associated_Device_or_Medical_Supply_PDI_3                          float64
#  77  Covered_or_Noncovered_Indicator_4                                  object
#  78  Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4          object
#  79  Product_Category_or_Therapeutic_Area_4                             object
#  80  Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4           object
#  81  Associated_Drug_or_Biological_NDC_4                                object
#  82  Associated_Device_or_Medical_Supply_PDI_4                          float64
#  83  Covered_or_Noncovered_Indicator_5                                  object
#  84  Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5          object
#  85  Product_Category_or_Therapeutic_Area_5                             object
#  86  Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5           object
#  87  Associated_Drug_or_Biological_NDC_5                                object
#  88  Associated_Device_or_Medical_Supply_PDI_5                          float64
#  89  Program_Year                                                       int64
#  90  Payment_Publication_Date                                           object
# dtypes: float64(20), int64(4), object(67)
# memory usage: 3.9+ GB

# %%
gen_pay_2020_df.head(5)
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN
# 0   UNCHANGED  Covered Recipient Physician                    NaN  \
# 1   UNCHANGED  Covered Recipient Physician                    NaN
# 2   UNCHANGED  Covered Recipient Physician                    NaN
# 3   UNCHANGED  Covered Recipient Physician                    NaN
# 4   UNCHANGED  Covered Recipient Physician                    NaN
#
#    Teaching_Hospital_ID Teaching_Hospital_Name  Covered_Recipient_Profile_ID
# 0                   NaN                    NaN                      557946.0  \
# 1                   NaN                    NaN                      276936.0
# 2                   NaN                    NaN                     1275463.0
# 3                   NaN                    NaN                      268352.0
# 4                   NaN                    NaN                      904225.0
#
#    Covered_Recipient_NPI Covered_Recipient_First_Name
# 0           1.841302e+09                        Vikas  \
# 1           1.093896e+09                      Matthew
# 2           1.154534e+09                      Stephen
# 3           1.902872e+09                        Leroy
# 4           1.003949e+09                      Michael
#
#   Covered_Recipient_Middle_Name Covered_Recipient_Last_Name  ...
# 0                         Kumar                       Pilly  ...  \
# 1                           NaN                        Hall  ...
# 2                           NaN                    Campbell  ...
# 3                        Pearce                     McCarty  ...
# 4                          John                       Latza  ...
#
#   Associated_Drug_or_Biological_NDC_4
# 0                                 NaN  \
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   Associated_Device_or_Medical_Supply_PDI_4 Covered_or_Noncovered_Indicator_5
# 0                                       NaN                               NaN  \
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 4                                       NaN                               NaN
#
#   Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5
# 0                                                NaN         \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Product_Category_or_Therapeutic_Area_5
# 0                                    NaN  \
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5
# 0                                                NaN        \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Associated_Drug_or_Biological_NDC_5
# 0                                 NaN  \
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   Associated_Device_or_Medical_Supply_PDI_5 Program_Year
# 0                                       NaN         2020  \
# 1                                       NaN         2020
# 2                                       NaN         2020
# 3                                       NaN         2020
# 4                                       NaN         2020
#
#   Payment_Publication_Date
# 0               01/20/2023
# 1               01/20/2023
# 2               01/20/2023
# 3               01/20/2023
# 4               01/20/2023
#
# [5 rows x 91 columns]

# %%
#Check nulls
gen_pay_2020_df.isnull().sum()
# Out:
# Change_Type                                                       0
# Covered_Recipient_Type                                            0
# Teaching_Hospital_CCN                                       5790756
# Teaching_Hospital_ID                                        5790756
# Teaching_Hospital_Name                                      5790756
#                                                              ...
# Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5    5784134
# Associated_Drug_or_Biological_NDC_5                         5805453
# Associated_Device_or_Medical_Supply_PDI_5                   5823162
# Program_Year                                                      0
# Payment_Publication_Date                                          0
# Length: 91, dtype: int64

# %%
# Checking columns
gen_pay_2020_df.columns
# Out:
# Index(['Change_Type', 'Covered_Recipient_Type', 'Teaching_Hospital_CCN',
#        'Teaching_Hospital_ID', 'Teaching_Hospital_Name',
#        'Covered_Recipient_Profile_ID', 'Covered_Recipient_NPI',
#        'Covered_Recipient_First_Name', 'Covered_Recipient_Middle_Name',
#        'Covered_Recipient_Last_Name', 'Covered_Recipient_Name_Suffix',
#        'Recipient_Primary_Business_Street_Address_Line1',
#        'Recipient_Primary_Business_Street_Address_Line2', 'Recipient_City',
#        'Recipient_State', 'Recipient_Zip_Code', 'Recipient_Country',
#        'Recipient_Province', 'Recipient_Postal_Code',
#        'Covered_Recipient_Primary_Type_1', 'Covered_Recipient_Primary_Type_2',
#        'Covered_Recipient_Primary_Type_3', 'Covered_Recipient_Primary_Type_4',
#        'Covered_Recipient_Primary_Type_5', 'Covered_Recipient_Primary_Type_6',
#        'Covered_Recipient_Specialty_1', 'Covered_Recipient_Specialty_2',
#        'Covered_Recipient_Specialty_3', 'Covered_Recipient_Specialty_4',
#        'Covered_Recipient_Specialty_5', 'Covered_Recipient_Specialty_6',
#        'Covered_Recipient_License_State_code1',
#        'Covered_Recipient_License_State_code2',
#        'Covered_Recipient_License_State_code3',
#        'Covered_Recipient_License_State_code4',
#        'Covered_Recipient_License_State_code5',
#        'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country',
#        'Total_Amount_of_Payment_USDollars', 'Date_of_Payment',
#        'Number_of_Payments_Included_in_Total_Amount',
#        'Form_of_Payment_or_Transfer_of_Value',
#        'Nature_of_Payment_or_Transfer_of_Value', 'City_of_Travel',
#        'State_of_Travel', 'Country_of_Travel', 'Physician_Ownership_Indicator',
#        'Third_Party_Payment_Recipient_Indicator',
#        'Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value',
#        'Charity_Indicator', 'Third_Party_Equals_Covered_Recipient_Indicator',
#        'Contextual_Information', 'Delay_in_Publication_Indicator', 'Record_ID',
#        'Dispute_Status_for_Publication', 'Related_Product_Indicator',
#        'Covered_or_Noncovered_Indicator_1',
#        'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1',
#        'Product_Category_or_Therapeutic_Area_1',
#        'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1',
#        'Associated_Drug_or_Biological_NDC_1',
#        'Associated_Device_or_Medical_Supply_PDI_1',
#        'Covered_or_Noncovered_Indicator_2',
#        'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2',
#        'Product_Category_or_Therapeutic_Area_2',
#        'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2',
#        'Associated_Drug_or_Biological_NDC_2',
#        'Associated_Device_or_Medical_Supply_PDI_2',
#        'Covered_or_Noncovered_Indicator_3',
#        'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3',
#        'Product_Category_or_Therapeutic_Area_3',
#        'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3',
#        'Associated_Drug_or_Biological_NDC_3',
#        'Associated_Device_or_Medical_Supply_PDI_3',
#        'Covered_or_Noncovered_Indicator_4',
#        'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4',
#        'Product_Category_or_Therapeutic_Area_4',
#        'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4',
#        'Associated_Drug_or_Biological_NDC_4',
#        'Associated_Device_or_Medical_Supply_PDI_4',
#        'Covered_or_Noncovered_Indicator_5',
#        'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5',
#        'Product_Category_or_Therapeutic_Area_5',
#        'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5',
#        'Associated_Drug_or_Biological_NDC_5',
#        'Associated_Device_or_Medical_Supply_PDI_5', 'Program_Year',
#        'Payment_Publication_Date'],
#       dtype='object')

# %%
# drop columns
gen_pay_2020_df = gen_pay_2020_df.drop(columns = ['Covered_Recipient_Middle_Name','Covered_Recipient_Name_Suffix','Recipient_Province',
                                     'Recipient_Postal_Code','Contextual_Information','Covered_or_Noncovered_Indicator_1',
                                     'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1','Product_Category_or_Therapeutic_Area_1',
                                     'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1','Associated_Drug_or_Biological_NDC_1',
                                     'Associated_Device_or_Medical_Supply_PDI_1','Covered_or_Noncovered_Indicator_2',
                                     'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2','Product_Category_or_Therapeutic_Area_2',
                                     'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2','Associated_Drug_or_Biological_NDC_2',
                                     'Associated_Device_or_Medical_Supply_PDI_2','Covered_or_Noncovered_Indicator_3',
                                     'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3','Product_Category_or_Therapeutic_Area_3',
                                     'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3','Associated_Drug_or_Biological_NDC_3',
                                     'Associated_Device_or_Medical_Supply_PDI_3','Covered_or_Noncovered_Indicator_4',
                                     'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4','Product_Category_or_Therapeutic_Area_4',
                                     'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4','Associated_Drug_or_Biological_NDC_4',
                                     'Associated_Device_or_Medical_Supply_PDI_4','Covered_or_Noncovered_Indicator_5',
                                     'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5','Product_Category_or_Therapeutic_Area_5',
                                     'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5','Associated_Drug_or_Biological_NDC_5',
                                     'Associated_Device_or_Medical_Supply_PDI_5'])

# %%
#Checking updated number of columns
gen_pay_2020_df.shape
# Out:
# (5823162, 56)

# %%
# Checking the updated list of columns
gen_pay_2020_df.columns
# Out:
# Index(['Change_Type', 'Covered_Recipient_Type', 'Teaching_Hospital_CCN',
#        'Teaching_Hospital_ID', 'Teaching_Hospital_Name',
#        'Covered_Recipient_Profile_ID', 'Covered_Recipient_NPI',
#        'Covered_Recipient_First_Name', 'Covered_Recipient_Last_Name',
#        'Recipient_Primary_Business_Street_Address_Line1',
#        'Recipient_Primary_Business_Street_Address_Line2', 'Recipient_City',
#        'Recipient_State', 'Recipient_Zip_Code', 'Recipient_Country',
#        'Covered_Recipient_Primary_Type_1', 'Covered_Recipient_Primary_Type_2',
#        'Covered_Recipient_Primary_Type_3', 'Covered_Recipient_Primary_Type_4',
#        'Covered_Recipient_Primary_Type_5', 'Covered_Recipient_Primary_Type_6',
#        'Covered_Recipient_Specialty_1', 'Covered_Recipient_Specialty_2',
#        'Covered_Recipient_Specialty_3', 'Covered_Recipient_Specialty_4',
#        'Covered_Recipient_Specialty_5', 'Covered_Recipient_Specialty_6',
#        'Covered_Recipient_License_State_code1',
#        'Covered_Recipient_License_State_code2',
#        'Covered_Recipient_License_State_code3',
#        'Covered_Recipient_License_State_code4',
#        'Covered_Recipient_License_State_code5',
#        'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country',
#        'Total_Amount_of_Payment_USDollars', 'Date_of_Payment',
#        'Number_of_Payments_Included_in_Total_Amount',
#        'Form_of_Payment_or_Transfer_of_Value',
#        'Nature_of_Payment_or_Transfer_of_Value', 'City_of_Travel',
#        'State_of_Travel', 'Country_of_Travel', 'Physician_Ownership_Indicator',
#        'Third_Party_Payment_Recipient_Indicator',
#        'Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value',
#        'Charity_Indicator', 'Third_Party_Equals_Covered_Recipient_Indicator',
#        'Delay_in_Publication_Indicator', 'Record_ID',
#        'Dispute_Status_for_Publication', 'Related_Product_Indicator',
#        'Program_Year', 'Payment_Publication_Date'],
#       dtype='object')

# %%
# Checking updated info
gen_pay_2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5823162 entries, 0 to 5823161
# Data columns (total 56 columns):
#  #   Column                                                             Dtype
# ---  ------                                                             -----
#  0   Change_Type                                                        object
#  1   Covered_Recipient_Type                                             object
#  2   Teaching_Hospital_CCN                                              float64
#  3   Teaching_Hospital_ID                                               float64
#  4   Teaching_Hospital_Name                                             object
#  5   Covered_Recipient_Profile_ID                                       float64
#  6   Covered_Recipient_NPI                                              float64
#  7   Covered_Recipient_First_Name                                       object
#  8   Covered_Recipient_Last_Name                                        object
#  9   Recipient_Primary_Business_Street_Address_Line1                    object
#  10  Recipient_Primary_Business_Street_Address_Line2                    object
#  11  Recipient_City                                                     object
#  12  Recipient_State                                                    object
#  13  Recipient_Zip_Code                                                 object
#  14  Recipient_Country                                                  object
#  15  Covered_Recipient_Primary_Type_1                                   object
#  16  Covered_Recipient_Primary_Type_2                                   float64
#  17  Covered_Recipient_Primary_Type_3                                   float64
#  18  Covered_Recipient_Primary_Type_4                                   float64
#  19  Covered_Recipient_Primary_Type_5                                   float64
#  20  Covered_Recipient_Primary_Type_6                                   float64
#  21  Covered_Recipient_Specialty_1                                      object
#  22  Covered_Recipient_Specialty_2                                      float64
#  23  Covered_Recipient_Specialty_3                                      float64
#  24  Covered_Recipient_Specialty_4                                      float64
#  25  Covered_Recipient_Specialty_5                                      float64
#  26  Covered_Recipient_Specialty_6                                      float64
#  27  Covered_Recipient_License_State_code1                              object
#  28  Covered_Recipient_License_State_code2                              object
#  29  Covered_Recipient_License_State_code3                              object
#  30  Covered_Recipient_License_State_code4                              object
#  31  Covered_Recipient_License_State_code5                              object
#  32  Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name          object
#  33  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID        int64
#  34  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name      object
#  35  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State     object
#  36  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country   object
#  37  Total_Amount_of_Payment_USDollars                                  float64
#  38  Date_of_Payment                                                    object
#  39  Number_of_Payments_Included_in_Total_Amount                        int64
#  40  Form_of_Payment_or_Transfer_of_Value                               object
#  41  Nature_of_Payment_or_Transfer_of_Value                             object
#  42  City_of_Travel                                                     object
#  43  State_of_Travel                                                    object
#  44  Country_of_Travel                                                  object
#  45  Physician_Ownership_Indicator                                      object
#  46  Third_Party_Payment_Recipient_Indicator                            object
#  47  Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value  object
#  48  Charity_Indicator                                                  object
#  49  Third_Party_Equals_Covered_Recipient_Indicator                     object
#  50  Delay_in_Publication_Indicator                                     object
#  51  Record_ID                                                          int64
#  52  Dispute_Status_for_Publication                                     object
#  53  Related_Product_Indicator                                          object
#  54  Program_Year                                                       int64
#  55  Payment_Publication_Date                                           object
# dtypes: float64(15), int64(4), object(37)
# memory usage: 2.4+ GB

# %%
# Data type consistency
gen_pay_2020_df['Covered_Recipient_Specialty_1']
# Out:
# 0          Allopathic & Osteopathic Physicians|Pain Medic...
# 1                                   Dental Providers|Dentist
# 2                                   Dental Providers|Dentist
# 3          Allopathic & Osteopathic Physicians|Orthopaedi...
# 4                        Chiropractic Providers|Chiropractor
#                                  ...
# 5823157    Allopathic & Osteopathic Physicians|Internal M...
# 5823158    Allopathic & Osteopathic Physicians|Internal M...
# 5823159    Allopathic & Osteopathic Physicians|Internal M...
# 5823160    Allopathic & Osteopathic Physicians|Internal M...
# 5823161    Allopathic & Osteopathic Physicians|Internal M...
# Name: Covered_Recipient_Specialty_1, Length: 5823162, dtype: object

# %%
# Data type consistency
gen_pay_2020_df['Covered_Recipient_Specialty_2']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#            ..
# 5823157   NaN
# 5823158   NaN
# 5823159   NaN
# 5823160   NaN
# 5823161   NaN
# Name: Covered_Recipient_Specialty_2, Length: 5823162, dtype: float64

# %%
#Checking data type consistency
gen_pay_2020_df['Covered_Recipient_Primary_Type_1']
# Out:
# 0               Medical Doctor
# 1          Doctor of Dentistry
# 2          Doctor of Dentistry
# 3               Medical Doctor
# 4                 Chiropractor
#                   ...
# 5823157         Medical Doctor
# 5823158         Medical Doctor
# 5823159         Medical Doctor
# 5823160         Medical Doctor
# 5823161         Medical Doctor
# Name: Covered_Recipient_Primary_Type_1, Length: 5823162, dtype: object

# %%
# Checking data type consistency
gen_pay_2020_df['Covered_Recipient_Primary_Type_2']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#            ..
# 5823157   NaN
# 5823158   NaN
# 5823159   NaN
# 5823160   NaN
# 5823161   NaN
# Name: Covered_Recipient_Primary_Type_2, Length: 5823162, dtype: float64

# %%
# dropping more columns
gen_pay_2020_df = gen_pay_2020_df.drop(columns = ['Covered_Recipient_Specialty_2','Covered_Recipient_Specialty_3','Covered_Recipient_Specialty_4',
                                                 'Covered_Recipient_Specialty_5','Covered_Recipient_Specialty_6','Covered_Recipient_Primary_Type_2',
                                                 'Covered_Recipient_Primary_Type_3','Covered_Recipient_Primary_Type_4',
                                                  'Covered_Recipient_Primary_Type_5', 'Covered_Recipient_Primary_Type_6'])

# %%
#Checking updated info
gen_pay_2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5823162 entries, 0 to 5823161
# Data columns (total 46 columns):
#  #   Column                                                             Dtype
# ---  ------                                                             -----
#  0   Change_Type                                                        object
#  1   Covered_Recipient_Type                                             object
#  2   Teaching_Hospital_CCN                                              float64
#  3   Teaching_Hospital_ID                                               float64
#  4   Teaching_Hospital_Name                                             object
#  5   Covered_Recipient_Profile_ID                                       float64
#  6   Covered_Recipient_NPI                                              float64
#  7   Covered_Recipient_First_Name                                       object
#  8   Covered_Recipient_Last_Name                                        object
#  9   Recipient_Primary_Business_Street_Address_Line1                    object
#  10  Recipient_Primary_Business_Street_Address_Line2                    object
#  11  Recipient_City                                                     object
#  12  Recipient_State                                                    object
#  13  Recipient_Zip_Code                                                 object
#  14  Recipient_Country                                                  object
#  15  Covered_Recipient_Primary_Type_1                                   object
#  16  Covered_Recipient_Specialty_1                                      object
#  17  Covered_Recipient_License_State_code1                              object
#  18  Covered_Recipient_License_State_code2                              object
#  19  Covered_Recipient_License_State_code3                              object
#  20  Covered_Recipient_License_State_code4                              object
#  21  Covered_Recipient_License_State_code5                              object
#  22  Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name          object
#  23  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID        int64
#  24  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name      object
#  25  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State     object
#  26  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country   object
#  27  Total_Amount_of_Payment_USDollars                                  float64
#  28  Date_of_Payment                                                    object
#  29  Number_of_Payments_Included_in_Total_Amount                        int64
#  30  Form_of_Payment_or_Transfer_of_Value                               object
#  31  Nature_of_Payment_or_Transfer_of_Value                             object
#  32  City_of_Travel                                                     object
#  33  State_of_Travel                                                    object
#  34  Country_of_Travel                                                  object
#  35  Physician_Ownership_Indicator                                      object
#  36  Third_Party_Payment_Recipient_Indicator                            object
#  37  Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value  object
#  38  Charity_Indicator                                                  object
#  39  Third_Party_Equals_Covered_Recipient_Indicator                     object
#  40  Delay_in_Publication_Indicator                                     object
#  41  Record_ID                                                          int64
#  42  Dispute_Status_for_Publication                                     object
#  43  Related_Product_Indicator                                          object
#  44  Program_Year                                                       int64
#  45  Payment_Publication_Date                                           object
# dtypes: float64(5), int64(4), object(37)
# memory usage: 2.0+ GB

# %%
# Checking updated number of columns and rows
gen_pay_2020_df.shape
# Out:
# (5823162, 46)

# %%
# Updating Date data types
gen_pay_2020_df['Date_of_Payment'] = pd.to_datetime(gen_pay_2020_df["Date_of_Payment"])
gen_pay_2020_df['Date_of_Payment']
# Out:
# 0         2020-08-19
# 1         2020-06-16
# 2         2020-08-02
# 3         2020-03-19
# 4         2020-10-13
#              ...
# 5823157   2020-12-07
# 5823158   2020-08-25
# 5823159   2020-08-25
# 5823160   2020-12-07
# 5823161   2020-08-11
# Name: Date_of_Payment, Length: 5823162, dtype: datetime64[ns]

# %%
# Updating Date data types
gen_pay_2020_df['Payment_Publication_Date'] = pd.to_datetime(gen_pay_2020_df["Payment_Publication_Date"])

# %%
gen_pay_2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5823162 entries, 0 to 5823161
# Data columns (total 46 columns):
#  #   Column                                                             Dtype
# ---  ------                                                             -----
#  0   Change_Type                                                        object
#  1   Covered_Recipient_Type                                             object
#  2   Teaching_Hospital_CCN                                              float64
#  3   Teaching_Hospital_ID                                               float64
#  4   Teaching_Hospital_Name                                             object
#  5   Covered_Recipient_Profile_ID                                       float64
#  6   Covered_Recipient_NPI                                              float64
#  7   Covered_Recipient_First_Name                                       object
#  8   Covered_Recipient_Last_Name                                        object
#  9   Recipient_Primary_Business_Street_Address_Line1                    object
#  10  Recipient_Primary_Business_Street_Address_Line2                    object
#  11  Recipient_City                                                     object
#  12  Recipient_State                                                    object
#  13  Recipient_Zip_Code                                                 object
#  14  Recipient_Country                                                  object
#  15  Covered_Recipient_Primary_Type_1                                   object
#  16  Covered_Recipient_Specialty_1                                      object
#  17  Covered_Recipient_License_State_code1                              object
#  18  Covered_Recipient_License_State_code2                              object
#  19  Covered_Recipient_License_State_code3                              object
#  20  Covered_Recipient_License_State_code4                              object
#  21  Covered_Recipient_License_State_code5                              object
#  22  Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name          object
#  23  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID        int64
#  24  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name      object
#  25  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State     object
#  26  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country   object
#  27  Total_Amount_of_Payment_USDollars                                  float64
#  28  Date_of_Payment                                                    datetime64[ns]
#  29  Number_of_Payments_Included_in_Total_Amount                        int64
#  30  Form_of_Payment_or_Transfer_of_Value                               object
#  31  Nature_of_Payment_or_Transfer_of_Value                             object
#  32  City_of_Travel                                                     object
#  33  State_of_Travel                                                    object
#  34  Country_of_Travel                                                  object
#  35  Physician_Ownership_Indicator                                      object
#  36  Third_Party_Payment_Recipient_Indicator                            object
#  37  Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value  object
#  38  Charity_Indicator                                                  object
#  39  Third_Party_Equals_Covered_Recipient_Indicator                     object
#  40  Delay_in_Publication_Indicator                                     object
#  41  Record_ID                                                          int64
#  42  Dispute_Status_for_Publication                                     object
#  43  Related_Product_Indicator                                          object
#  44  Program_Year                                                       int64
#  45  Payment_Publication_Date                                           datetime64[ns]
# dtypes: datetime64[ns](2), float64(5), int64(4), object(35)
# memory usage: 2.0+ GB

# %%
gen_pay_2020_df.head(5)
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN
# 0   UNCHANGED  Covered Recipient Physician                    NaN  \
# 1   UNCHANGED  Covered Recipient Physician                    NaN
# 2   UNCHANGED  Covered Recipient Physician                    NaN
# 3   UNCHANGED  Covered Recipient Physician                    NaN
# 4   UNCHANGED  Covered Recipient Physician                    NaN
#
#    Teaching_Hospital_ID Teaching_Hospital_Name  Covered_Recipient_Profile_ID
# 0                   NaN                    NaN                      557946.0  \
# 1                   NaN                    NaN                      276936.0
# 2                   NaN                    NaN                     1275463.0
# 3                   NaN                    NaN                      268352.0
# 4                   NaN                    NaN                      904225.0
#
#    Covered_Recipient_NPI Covered_Recipient_First_Name
# 0           1.841302e+09                        Vikas  \
# 1           1.093896e+09                      Matthew
# 2           1.154534e+09                      Stephen
# 3           1.902872e+09                        Leroy
# 4           1.003949e+09                      Michael
#
#   Covered_Recipient_Last_Name Recipient_Primary_Business_Street_Address_Line1
# 0                       Pilly                         400 International Drive  \
# 1                        Hall                             301 Prospect Avenue
# 2                    Campbell                                 228 Ravine Road
# 3                     McCarty                             8100 W. 78th Street
# 4                       Latza                                 212 Park Avenue
#
#    ... Third_Party_Payment_Recipient_Indicator
# 0  ...                  No Third Party Payment  \
# 1  ...                  No Third Party Payment
# 2  ...                  No Third Party Payment
# 3  ...                  No Third Party Payment
# 4  ...                  No Third Party Payment
#
#   Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value
# 0                                                NaN                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Charity_Indicator Third_Party_Equals_Covered_Recipient_Indicator
# 0               NaN                                            NaN  \
# 1               NaN                                            NaN
# 2               NaN                                            NaN
# 3               NaN                                            NaN
# 4               NaN                                            NaN
#
#   Delay_in_Publication_Indicator  Record_ID Dispute_Status_for_Publication
# 0                             No  709231379                             No  \
# 1                             No  709230901                             No
# 2                             No  709230907                             No
# 3                             No  709231369                             No
# 4                             No  709231357                             No
#
#   Related_Product_Indicator Program_Year Payment_Publication_Date
# 0                        No         2020               2023-01-20
# 1                        No         2020               2023-01-20
# 2                        No         2020               2023-01-20
# 3                        No         2020               2023-01-20
# 4                        No         2020               2023-01-20
#
# [5 rows x 46 columns]

# %%
gen_pay_2020_df.to_csv('cleaned-gen-pay-2020-data.csv', index=False)
